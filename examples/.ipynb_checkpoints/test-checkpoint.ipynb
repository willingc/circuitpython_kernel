# %%
import board
import nativeio

# %%
import sys

# %%
print(sys.__name__)
# Out:
# sys

# %%
print(sys.implementation)
# Out:
# (name='circuitpython', version=(0, 9, 1))

# %%
print(sys.platform)
# Out:
# Atmel SAMD21

# %%
sys.platform
